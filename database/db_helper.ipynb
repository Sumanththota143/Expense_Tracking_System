# %%
#importing connector
import mysql.connector

#create a connector
connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="root" ,
    database="expense_tracker"
)

# %%
if connection.is_connected():
    print("Successfully connected to the database!")
else:
    print("database connection failed")
# Out:
# Successfully connected to the database!

# %%
#create a cursor 
cursor = connection.cursor()
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[10], line 2
#       1 #create a cursor
# ----> 2 cursor = connection.cursor()
#
# File c:\Users\Sumanth\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\connection.py:1403, in MySQLConnection.cursor(self, buffered, raw, prepared, cursor_class, dictionary, read_timeout, write_timeout)
#    1372 def cursor(
#    1373     self,
#    1374     buffered: Optional[bool] = None,
#    (...)   1380     write_timeout: Optional[int] = None,
#    1381 ) -> MySQLCursor:
#    1382     """Instantiates and returns a cursor
#    1383
#    1384     By default, MySQLCursor is returned. Depending on the options
#    (...)   1401     Returns a cursor-object
#    1402     """
# -> 1403     self.handle_unread_result()
#    1405     if not self.is_connected():
#    1406         raise OperationalError("MySQL Connection not available")
#
# File c:\Users\Sumanth\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\connection.py:1784, in MySQLConnection.handle_unread_result(self)
#    1782     self.consume_results()
#    1783 elif self.unread_result:
# -> 1784     raise InternalError("Unread result found")
#
# InternalError: Unread result found
